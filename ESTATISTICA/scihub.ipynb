# %%
import scihub2pdf
import os

# %%
import pandas as pd
pd.options.display.max_rows = 999

# %%
os.system("python scihub2pdf 10.1371/journal.pone.0163477")
# Out:
# 2

# %%
os.system("python C:\Anaconda3\lib\site-packages\scihub2pdf\bin\scihub2pdf 10.1186/s40561-017-0050-x")
# Out:
# 2

# %%
scihub2pdf.__file__
# Out:
# 'C:\\Anaconda3\\lib\\site-packages\\scihub2pdf\\__init__.py'

# %%
link = 'https://link.springer.com/search/csv?facet-content-type=%22Article%22&query=blockchain'

springer = pd.read_csv(link)

# %%
springer.head()
# Out:
#                                       Document Title  \
# 0                 Blockchain platforms: A compendium
# 1  Blockchain and the Internet of Things in the I...
# 2  IoTChain: A blockchain security architecture f...
# 3  BCTrust: A decentralized authentication blockc...
# 4  Accelerating Blockchain Search of Full Nodes U...
#
#                                              Authors  \
# 0                               C. Saraf; S. Sabadra
# 1                                          D. Miller
# 2  O. Alphand; M. Amoretti; T. Claeys; S. Dall'As...
# 3             M. T. Hammi; P. Bellot; A. Serhrouchni
# 4                         S. Morishima; H. Matsutani
#
#                                  Author Affiliations  \
# 0  Department of Computer Engineering, Pune Insti...
# 1                                                IBM
# 2  Univ. Grenoble Alpes, CNRS, Grenoble INP, LIG,...
# 3  LTCI, T&#x00E9;l&#x00E9;com ParisTech, Univers...
# ...

# %%
springer.columns
# Out:
# Index(['Item Title', 'Publication Title', 'Book Series Title',
#        'Journal Volume', 'Journal Issue', 'Item DOI', 'Authors',
#        'Publication Year', 'URL', 'Content Type'],
#       dtype='object')

# %%
springer.shape
# Out:
# (351, 10)

# %%
for index, row in springer.iterrows():
    print(row['Item DOI'].split('/')[0],row['Item DOI'],row['Item Title'],row['Publication Year'])
# Out:
# 10.1186 10.1186/s40854-017-0059-8 Erratum to: Overview of business innovations and research opportunities in blockchain and introduction to the special issue 2017
# 10.1186 10.1186/s40854-016-0040-y Blockchain-based sharing services: What blockchain technology can contribute to smart cities 2016
# 10.1186 10.1186/s40561-017-0050-x Exploring blockchain technology and its potential applications for education 2018
# 10.1007 10.1007/s42354-018-0007-4 1. Blockchain 2018
# 10.1007 10.1007/s42354-018-0081-7 2. Blockchain 2018
# 10.1186 10.1186/s40852-018-0086-3 Blockchain government - a next form of infrastructure for the twenty-first century 2018
# 10.1007 10.1007/s10586-018-2387-5 Analysis of Blockchain technology: pros, cons and SWOT 2018
# 10.1007 10.1007/s12599-017-0506-0 A Blockchain Research Framework 2017
# 10.1007 10.1007/s11623-017-0813-0 Alle reden über Blockchain 2017
# ...

# %%
link = 'https://ieeexplore.ieee.org/search/searchExport.jsp?queryText=climate%20change&newsearch=true&refinements=4294967116&refinements=4291944246&refinements=4291944245'
ieee = pd.read_csv(link, sep=',', encoding='latin1')
# Out:
# -------------------------------------------
# ParserErrorTraceback (most recent call last)
# <ipython-input-10-15b6ca5915b4> in <module>()
#       1 link = 'https://ieeexplore.ieee.org/search/searchExport.jsp?queryText=climate%20change&newsearch=true&refinements=4294967116&refinements=4291944246&refinements=4291944245'
# ----> 2 ieee = pd.read_csv(link, sep=',', encoding='latin1')
#
# ...

# %%
ieee.columns

# %%
ieee.tail(100)

# %%
for c in ieee.columns:
    print(ieee[c][0])
# Out:
# Accelerating Blockchain Search of Full Nodes Using GPUs
# S. Morishima; H. Matsutani
# nan
# 2018 26th Euromicro International Conference on Parallel, Distributed and Network-based Processing (PDP)
# 20180607.0
# 2018
# nan
# nan
# 244
# 248
# ...

# %%
print(ieee['DOI'])
# Out:
# 0                             10.1109/PDP2018.2018.00041
# 1                          10.1109/VLSI-DAT.2018.8373269
# 2                             10.1109/PDP2018.2018.00105
# 3                            10.1109/ICEDEG.2018.8372356
# 4                       10.1109/IOT-TUSCANY.2018.8373021
# 5                            10.1109/ACCESS.2018.2844400
# 6                          10.1109/MENACOMM.2018.8371010
# 7                               10.1109/SDS.2018.8370413
# 8                              10.1109/MNET.2018.1700344
# 9                                10.1109/LT.2018.8368494
# 10                             10.1109/ICPADS.2017.00041
# 11                           10.1109/ACCESS.2018.2842685
# 12                            10.1109/WCNCW.2018.8368983
# 13                             10.1109/ICPADS.2017.00113
# 14                             10.1109/ICPADS.2017.00111
# 15                             10.1109/ICPADS.2017.00112
# ...
