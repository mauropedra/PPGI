# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from collections import Counter

# %%
dir = 'C:/_dados/'

# %%
train = pd.read_csv(dir + 'train.csv', sep=',',index_col=0, dtype={11:'str',12:'str'})
test = pd.read_csv(dir + 'test.csv', sep=',',index_col=0, dtype={11:'str',12:'str'})
resources = pd.read_csv(dir + 'resources.csv', sep=',',index_col=0)

# %%
train.groupby('project_subject_categories')['project_is_approved'].mean().sort_values(ascending = False)
# Out:
# project_subject_categories
# Warmth, Care & Hunger                         0.921953
# Health & Sports, Warmth, Care & Hunger        0.903226
# History & Civics, Health & Sports             0.900000
# Literacy & Language, History & Civics         0.890494
# History & Civics, Literacy & Language         0.885490
# Literacy & Language                           0.869858
# Literacy & Language, Math & Science           0.867219
# Music & The Arts, Special Needs               0.863830
# Applied Learning, Literacy & Language         0.861208
# Health & Sports, Special Needs                0.861064
# Math & Science, Literacy & Language           0.861046
# Literacy & Language, Applied Learning         0.859345
# Math & Science, History & Civics              0.858326
# Literacy & Language, Special Needs            0.854450
# History & Civics, Math & Science              0.853333
# Health & Sports, Applied Learning             0.851852
# Music & The Arts                              0.850006
# Health & Sports, Math & Science               0.848936
# Health & Sports, Literacy & Language          0.847859
# Health & Sports                               0.846794
# Literacy & Language, Warmth, Care & Hunger    0.840000
# Literacy & Language, Music & The Arts         0.838777
# Math & Science, Applied Learning              0.832448
# History & Civics                              0.831974
# Math & Science, Music & The Arts              0.827961
# Special Needs, Music & The Arts               0.827255
# Math & Science, Special Needs                 0.825581
# History & Civics, Music & The Arts            0.821691
# Math & Science                                0.821082
# Health & Sports, History & Civics             0.820896
# History & Civics, Special Needs               0.815348
# Applied Learning                              0.814897
# Applied Learning, Health & Sports             0.813360
# Applied Learning, Special Needs               0.811769
# Applied Learning, Music & The Arts            0.809831
# Special Needs                                 0.809483
# Applied Learning, Math & Science              0.803624
# Applied Learning, History & Civics            0.795380
# Music & The Arts, History & Civics            0.793103
# Health & Sports, Music & The Arts             0.782443
# Math & Science, Health & Sports               0.780488
# Literacy & Language, Health & Sports          0.771654
# Special Needs, Warmth, Care & Hunger          0.771429
# Special Needs, Health & Sports                0.765625
# History & Civics, Applied Learning            0.753846
# Music & The Arts, Applied Learning            0.714286
# Music & The Arts, Warmth, Care & Hunger       0.666667
# Music & The Arts, Health & Sports             0.656250
# Applied Learning, Warmth, Care & Hunger       0.636364
# Math & Science, Warmth, Care & Hunger         0.631579
# History & Civics, Warmth, Care & Hunger       0.000000
# Name: project_is_approved, dtype: float64

# %%
train['project_subject_categories'] =  train['project_subject_categories'].str.replace('Warmth,','Warmth').str.replace(', ',',').str.replace('& ','').str.replace(' ','_')

# %%
train[['cat1','cat2']] = train['project_subject_categories'].str.split(',', expand=True)

# %%
resources['total'] = resources.quantity * resources.price
expenses = resources.groupby('id')['total'].sum()
expenses.head()
# Out:
# id
# p000001     833.63
# p000002     630.28
# p000003     298.97
# p000004    1126.22
# p000005     702.31
# Name: total, dtype: float64

# %%
number_of_items = resources.groupby('id')['total'].count()
number_of_items.head()
# Out:
# id
# p000001     4
# p000002    14
# p000003     4
# p000004    95
# p000005     4
# Name: total, dtype: int64

# %%
train2 = train.join(expenses)
train2 = train2.join(number_of_items,rsuffix='1')
train2.rename(columns={'total1':'qnty'}, inplace=True)
train2
# Out:
#                                teacher_id teacher_prefix school_state  \
# id
# p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.           NV
# p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.           GA
# p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.           UT
# p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.           NC
# p013780  a63b5547a7239eae4c1872670848e61a            Mr.           CA
# p063374  403c6783e9286e51ab318fba40f8d729           Mrs.           DE
# p103285  4e156c5fb3eea2531601c8736f3751a7           Mrs.           MO
# p181781  c71f2ef13b4bc91afac61ca8fd4c0f9f           Mrs.           SC
# p114989  b580c11b1497a0a67317763b7f03eb27            Ms.           IN
# p191410  2071fb0af994f8f16e7c6ed0f35062a1           Mrs.           IL
# p030093  b9e731e16ad8669f37a43e5316518106        Teacher           VA
# p226941  103cc1667cf9361bf1c58c8425e76e95           Mrs.           CA
# p225747  4681d60136ea859084ab488f2254b219            Ms.           PA
# p173555  9b7f355e34bc9ca5740779b69ee14d8e           Mrs.           NY
# p055350  882c8ddea1d5c4c31976e34f20b461f9            Ms.           FL
# p060293  74c7a7de62df6005b718dfea1447c745           Mrs.           NJ
# p199435  d69e412550b14dd8286e347f726908c2            Mr.           TX
# p074849  5d710e545d6952a3c12bfb45a7f9f08c           Mrs.           IN
# p232007  e7a8f866e3174a77ffe37323f032a8ac           Mrs.           FL
# p037127  b21174f6246deadc11c2157a958d7953           Mrs.           LA
# p230221  3bfe21c62feb8fd744a696a36487b452           Mrs.           PA
# p116615  b3593a375f2cf7fd4469b928ffac1c95           Mrs.           NY
# p106275  4ee410ea0ea8a0b4660b56c2f3648bbf            Ms.           NC
# p070918  a22774168d7910adce6969c8d8faee7c            Mr.           TX
# p144291  fdf9938d5f9e381630384c2452b159e0           Mrs.           PA
# p116102  efc95ee511efe14d1955789663317432           Mrs.           NC
# p070029  b74b266d6e52c0348a8dcef8b0ea4a2b           Mrs.           NJ
# p107356  f4594111d55f22ee3ed5e8e4a1c2852b            Ms.           UT
# p031939  32a2fb6f6a1aca27a686cea452973f03            Mr.           ID
# p044085  65f5f57c7b035d58ec095602a8f7dcf6           Mrs.           OH
# ...                                   ...            ...          ...
# p046158  63869fc1d2a2a9ece5866e92bea00990            Ms.           TX
# p117186  46c053ed202d95f22b46490150dfd3c5           Mrs.           OH
# p252101  666ac9d13ef073a8322986f8950c2d4e            Ms.           NC
# p135316  3534053a22cae9524a01a433126e9888           Mrs.           FL
# p021728  738d94e0362a86ab1c636cc13ebb7a65            Ms.           FL
# p054114  c33e76ec158e3235560c283521951a70            Ms.           WI
# p034326  530f8a184748ef4cf3fbc4928ca44538            Mr.           NJ
# p149979  5a8186d9718c0a01035673100fa6f2da           Mrs.           FL
# p014629  74bed045eeb5ec6b700be7e866a06f98           Mrs.           FL
# p212015  07ec062d40d6d7f9e36c4bbead5e434a            Mr.           CA
# p046158        2016-06-07 22:07:16             Grades 3-5
# p117186        2017-01-09 13:09:44          Grades PreK-2
# p252101        2016-08-16 13:28:08          Grades PreK-2
# p135316        2016-07-30 22:52:22             Grades 6-8
# p021728        2017-01-09 16:19:30          Grades PreK-2
# p054114        2017-03-31 19:10:10             Grades 6-8
# p034326        2016-05-24 18:49:47            Grades 9-12
# p149979        2017-04-27 09:30:23             Grades 3-5
# p014629        2017-03-23 15:05:27          Grades PreK-2
# p212015        2016-09-18 20:17:12             Grades 6-8
# p110625        2016-06-10 17:12:18          Grades PreK-2
# p053417        2016-09-27 22:36:37          Grades PreK-2
# p053967        2016-05-12 16:32:52          Grades PreK-2
# p226452        2016-05-16 22:13:00             Grades 3-5
# p177332        2016-08-12 00:07:25             Grades 3-5
# p030914        2017-03-01 14:10:54             Grades 3-5
# p224932        2016-08-02 13:27:07          Grades PreK-2
# p245029        2016-08-19 19:13:56             Grades 3-5
# p154340        2016-05-30 11:25:10          Grades PreK-2
# p235466        2016-07-15 00:00:41          Grades PreK-2
# p068185        2017-04-20 10:09:38             Grades 6-8
# p248714        2016-05-28 23:50:29          Grades PreK-2
# p045565        2016-07-21 16:18:35          Grades PreK-2
# p078709        2016-11-09 13:32:05          Grades PreK-2
# p184627        2016-08-04 22:30:02             Grades 6-8
# p014188        2016-10-07 16:13:32             Grades 6-8
# p116452        2017-03-11 23:58:31            Grades 9-12
# p074761        2017-02-09 15:42:43             Grades 6-8
# p136737        2016-12-28 14:20:07          Grades PreK-2
# p190772        2016-05-15 20:25:14             Grades 3-5
#
#                  project_subject_categories  \
# id
# p036502                   Literacy_Language
# p039565        Music_The_Arts,Health_Sports
# p233823      Math_Science,Literacy_Language
# p185307                       Health_Sports
# p013780                       Health_Sports
# p063374  Applied_Learning,Literacy_Language
# p103285                       Health_Sports
# p181781  Applied_Learning,Literacy_Language
# p114989                        Math_Science
# p191410                   Literacy_Language
# p030093      Literacy_Language,Math_Science
# p226941      Literacy_Language,Math_Science
# p225747  Applied_Learning,Literacy_Language
# p173555                   Literacy_Language
# p055350                       Special_Needs
# p060293      Literacy_Language,Math_Science
# p199435      Literacy_Language,Math_Science
# p074849                        Math_Science
# p232007  Applied_Learning,Literacy_Language
# p037127      Applied_Learning,Special_Needs
# p230221                        Math_Science
# p116615     Applied_Learning,Music_The_Arts
# p106275                   Literacy_Language
# p070918      Literacy_Language,Math_Science
# p144291                   Literacy_Language
# p116102          Math_Science,Special_Needs
# p070029      Literacy_Language,Math_Science
# p107356      Math_Science,Literacy_Language
# p031939                   Literacy_Language
# p044085                   Literacy_Language
# ...                                     ...
# p046158                        Math_Science
# p117186                    Applied_Learning
# p252101      Literacy_Language,Math_Science
# p135316                      History_Civics
# p021728      Literacy_Language,Math_Science
# p054114                       Health_Sports
# p034326                        Math_Science
# p149979                   Literacy_Language
# p014629                   Literacy_Language
# p212015                       Health_Sports
# p110625                       Special_Needs
# p053417                       Health_Sports
# p053967                   Literacy_Language
# p226452      Literacy_Language,Math_Science
# p177332                       Special_Needs
# p030914      Literacy_Language,Math_Science
# p224932                       Health_Sports
# p245029                       Health_Sports
# p154340                   Literacy_Language
# p235466                    Applied_Learning
# p068185      Literacy_Language,Math_Science
# p248714      Literacy_Language,Math_Science
# p045565  Applied_Learning,Literacy_Language
# p078709                       Health_Sports
# p184627     Literacy_Language,Special_Needs
# p014188                        Math_Science
# p116452                      Music_The_Arts
# p074761                        Math_Science
# p136737                   Literacy_Language
# p190772                   Literacy_Language
#
#                        project_subject_subcategories  \
# id
# p036502                                     Literacy
# p039565                 Performing Arts, Team Sports
# p233823       Applied Sciences, Literature & Writing
# p185307                            Health & Wellness
# p013780                            Health & Wellness
# p063374    Character Education, Literature & Writing
# p103285                            Health & Wellness
# p181781      Early Development, Literature & Writing
# p114989                                  Mathematics
# p191410                                     Literacy
# p030093            Literature & Writing, Mathematics
# p226941                        Literacy, Mathematics
# p225747                Character Education, Literacy
# p173555                         Literature & Writing
# p055350                                Special Needs
# p060293                        Literacy, Mathematics
# p199435                             ESL, Mathematics
# p074849           Health & Life Science, Mathematics
# p232007  College & Career Prep, Literature & Writing
# p037127             Early Development, Special Needs
# p230221                             Applied Sciences
# p116615           Early Development, Performing Arts
# p106275                                     Literacy
# p070918            Literature & Writing, Mathematics
# p144291                                     Literacy
# p116102                   Mathematics, Special Needs
# p070029                        Literacy, Mathematics
# p107356  Environmental Science, Literature & Writing
# p031939                         Literature & Writing
# p044085                                     Literacy
# ...                                              ...
# p046158           Health & Life Science, Mathematics
# p117186                            Early Development
# p252101                        Literacy, Mathematics
# p135316                          Civics & Government
# p021728            Literature & Writing, Mathematics
# p054114                            Health & Wellness
# p034326                Applied Sciences, Mathematics
# p149979                         Literature & Writing
# p014629                  Foreign Languages, Literacy
# p212015                                Gym & Fitness
# p110625                                Special Needs
# p053417                                Gym & Fitness
# p053967               Literacy, Literature & Writing
# p226452                        Literacy, Mathematics
# p177332                                Special Needs
# p030914                        Literacy, Mathematics
# p224932             Gym & Fitness, Health & Wellness
# p245029             Gym & Fitness, Health & Wellness
# p154340                                     Literacy
# p235466                   Character Education, Other
# p068185            Literature & Writing, Mathematics
# p248714                        Literacy, Mathematics
# p045565      Early Development, Literature & Writing
# p078709                                  Team Sports
# p184627                      Literacy, Special Needs
# p014188                                  Mathematics
# p116452                              Performing Arts
# p074761      Applied Sciences, Environmental Science
# p136737                                     Literacy
# p190772                                     Literacy
#
#                                              project_title  \
# id
# p036502                           Super Sight Word Centers
# p039565                             Keep Calm and Dance On
# p233823                              Lets 3Doodle to Learn
# p185307  \"Kid Inspired\" Equipment to Increase Activit...
# p013780   We need clean water for our culinary arts class!
# p063374              Need to Reach Our Virtual  Mentors!!!
# p103285                              Active Kindergartners
# p181781               Fabulous Firsties-Wiggling to Learn!
# p114989              Wobble Chairs Help Fidgety Kids Focus
# p191410                        Snuggle Up With A Good Book
# p030093                         Writing, Writing, Writing!
# p226941                                  Technology Boost!
# p225747                      Life Lessons through Literacy
# p173555  Extra! Extra! Read all about it!!  We love to ...
# p055350                                   Flexible seating
# p060293                                      A Comfy Seat!
# p199435                      iPads for Bilingual Education
# p074849          Taking Learning Outside of the Classroom!
# p177332  Some of my students are non-verbal and lacks t...
# p030914  I am requesting support to purchase some Chrom...
# p224932  My students need to move while they are stuck ...
# p245029  Oddly enough, before we went on summer break, ...
# p154340  Due to the fact that I am a reading interventi...
# p235466  I recently read a fellow teacher blog explaini...
# p068185  These resources will be used in the classroom ...
# p248714  In order to make an my classroom an inviting e...
# p045565  It is my goal to teach my students to be indep...
# p078709  My students are some of the brightest in the d...
# p184627  I am asking for forty, new, young adult novels...
# p014188  Students seem to get board with math quickly a...
# p116452  I was taken back earlier in the year when I br...
# p074761  With this project, students will be able to ma...
# p136737  Have you ever went to the library to find a go...
# p190772  At the beginning of the school year, the readi...
#
#                                            project_essay_3  \
# id
# p036502                                                NaN
# p039565                                                NaN
# p233823                                                NaN
# p185307                                                NaN
# p013780                                                NaN
# p063374                                                NaN
# p103285                                                NaN
# p181781                                                NaN
# p114989                                                NaN
# p191410                                                NaN
# p030093                                                NaN
# p226941                                                NaN
# p225747                                                NaN
# p173555                                                NaN
# p055350                                                NaN
# p060293                                                NaN
# p199435                                                NaN
# p074849                                                NaN
# p232007  During our reading workshop. We do mini lesson...
# p037127                                                NaN
# p230221                                                NaN
# p116615                                                NaN
# p106275                                                NaN
# p070918                                                NaN
# p144291                                                NaN
# p116102                                                NaN
# p070029                                                NaN
# p107356                                                NaN
# p031939                                                NaN
# p044085                                                NaN
# ...                                                    ...
# p046158                                                NaN
# p117186                                                NaN
# p252101                                                NaN
# p135316                                                NaN
# p021728                                                NaN
# p054114                                                NaN
# p034326                                                NaN
# p149979                                                NaN
# p014629                                                NaN
# p212015                                                NaN
# p110625                                                NaN
# p053417                                                NaN
# p053967  My students will be spending time in the Readi...
# p226452  My students will use these materials in end of...
# p177332                                                NaN
# p030914                                                NaN
# p224932                                                NaN
# p245029                                                NaN
# p154340                                                NaN
# p235466                                                NaN
# p068185                                                NaN
# p248714                                                NaN
# p045565                                                NaN
# p078709                                                NaN
# p184627                                                NaN
# p014188                                                NaN
# p116452                                                NaN
# p074761                                                NaN
# p136737                                                NaN
# p190772  My students will be able to listen to books re...
#
#                                            project_essay_4  \
# id
# p036502                                                NaN
# p039565                                                NaN
# p233823                                                NaN
# p185307                                                NaN
# p013780                                                NaN
# p063374                                                NaN
# p103285                                                NaN
# p181781                                                NaN
# p114989                                                NaN
# p191410                                                NaN
# p030093                                                NaN
# p226941                                                NaN
# p225747                                                NaN
# p173555                                                NaN
# p055350                                                NaN
# p060293                                                NaN
# p199435                                                NaN
# p074849                                                NaN
# p232007  Your donations would greatly be a blessing for...
# p037127                                                NaN
# p230221                                                NaN
# p116615                                                NaN
# p106275                                                NaN
# p070918                                                NaN
# p144291                                                NaN
# p116102                                                NaN
# p070029                                                NaN
# p107356                                                NaN
# p031939                                                NaN
# p044085                                                NaN
# ...                                                    ...
# p046158                                                NaN
# p117186                                                NaN
# p252101                                                NaN
# p135316                                                NaN
# p021728                                                NaN
# p054114                                                NaN
# p034326                                                NaN
# p149979                                                NaN
# p014629                                                NaN
# p212015                                                NaN
# p110625                                                NaN
# p053417                                                NaN
# p053967  Students will be using technology to read and ...
# p226452  Your support of this project will help my stud...
# p177332                                                NaN
# p030914                                                NaN
# p224932                                                NaN
# p245029                                                NaN
# p154340                                                NaN
# p235466                                                NaN
# p068185                                                NaN
# p248714                                                NaN
# p045565                                                NaN
# p078709                                                NaN
# p184627                                                NaN
# p014188                                                NaN
# p116452                                                NaN
# p074761                                                NaN
# p136737                                                NaN
# p190772  Donations to this project will help my student...
#
#                                   project_resource_summary  \
# id
# p036502  My students need 6 Ipod Nano's to create and d...
# p039565  My students need matching shirts to wear for d...
# p233823  My students need the 3doodler. We are an SEM s...
# p185307  My students need balls and other activity equi...
# p013780  My students need a water filtration system for...
# p063374  My students need tablets  in order to communic...
# p103285  My students need stability stools and inflatab...
# p181781  My students need wiggle stools to allow them t...
# p114989  My students need seating that allows the most ...
# p191410  My students need 2 youth sized reclining chair...
# p030093  My students need individual dry erase boards t...
# p226941  My students need a projector and tablets to al...
# p225747  My students need books that teach life lessons...
# p173555  My students need good books, with life lessons...
# p055350  My students need flexible seating options to p...
# p060293  My students need cushions to sit on during cen...
# p199435  My students need to learn how to use technolog...
# p074849  My students need engaging math and science hom...
# p232007  My students need these reading materials to he...
# p037127  My students need manipulatives to pieces to gi...
# p230221  My students need opportunities to increase the...
# p116615  My students need the opportunity to develop or...
# p106275  My students need a leveled classroom library! ...
# p070918  My students need four iPad minis, and four pro...
# p144291  My students need leveled readers to maximize t...
# p116102  My students need balance ball chairs for the g...
# p070029  My students need hands -on education to help t...
# p107356  My students need earbud headphones to use in t...
# p031939  My students need 80 copies of \"The House of t...
# p044085  My students need Graphic Novels of high intere...
# ...                                                    ...
# p046158  My students need a Mimeo to provide them with ...
# p117186  My students need school supplies such as penci...
# p252101  My students need exercise balls and pump so th...
# p135316  My students need basic supplies in order to be...
# p021728  My students need a classroom carpet that gives...
# p054114  My students need j yoga mats to practice fitne...
# p034326  My students need math games on fractions, deci...
# p149979  My students need laptops to help with individu...
# p014629  My students need books in Spanish for our List...
# p212015  My students need sports supplies to help them ...
# p110625  My students need 3 Amazon-Fire Kids Edition-7\...
# p053417  My students need sport balls and jump ropes fo...
# p053967                      My students need Chromebooks.
# p226452  My students need just a little more support to...
# p177332  My students need 2 ipads to enhance their soci...
# p030914  My students need Chromebooks for the classroom...
# p224932  My students need 6 Hokki Stools to help get th...
# p245029  My students need ladder golf, 4-to-Score, Ramp...
# p154340  My students need resources, in addition to the...
# p235466  My students need flexible seating to allow for...
# p068185  My students need multiple seating options so t...
# p248714  My students need a rug for morning meeting and...
# p045565  My students need a writing center and shelving...
# p078709  My students need basketball equipment that can...
# p184627  My students need a collection of 40 young adul...
# p014188  My students need a way to have fun while worki...
# p116452  My students need this serger to make our costu...
# p074761  My students need a vinyl machine, button maker...
# p136737  My students need 3 shelf organizers to have a ...
# p190772  My students need a literacy listening center w...
#
#          teacher_number_of_previously_posted_projects  project_is_approved  \
# id
# p036502                                            26                    1
# p039565                                             1                    0
# p233823                                             5                    1
# p185307                                            16                    0
# p013780                                            42                    1
# p063374                                             0                    1
# p103285                                             1                    1
# p181781                                             0                    1
# p114989                                            13                    1
# p191410                                            12                    1
# p030093                                             1                    1
# p226941                                             1                    1
# p225747                                             3                    1
# p173555                                             5                    0
# p055350                                             0                    1
# p060293                                            11                    1
# p199435                                             3                    1
# p074849                                            64                    1
# p232007                                             6                    1
# p037127                                            34                    0
# p230221                                             0                    1
# p116615                                             0                    1
# p106275                                             5                    1
# p070918                                             0                    1
# p144291                                             8                    1
# p116102                                            28                    1
# p070029                                             3                    1
# p107356                                             6                    1
# p031939                                             0                    1
# p044085                                             1                    1
# ...                                               ...                  ...
# p046158                                             0                    1
# p117186                                             7                    1
# p252101                                             0                    1
# p135316                                             1                    0
# p021728                                             0                    1
# p054114                                             4                    1
# p034326                                            17                    1
# p149979                                             0                    1
# p014629                                             1                    1
# p212015                                             5                    0
# p110625                                             0                    1
# p053417                                             5                    1
# p053967                                             0                    1
# p226452                                             9                    0
# p177332                                             0                    1
# p030914                                             0                    1
# p224932                                             6                    1
# p245029                                            25                    1
# p154340                                             1                    0
# p235466                                             0                    1
# p068185                                             0                    0
# p248714                                             1                    1
# p045565                                             0                    1
# p078709                                             1                    0
# p184627                                            65                    1
# p014188                                             1                    1
# p116452                                             0                    1
# p074761                                            48                    0
# p136737                                            29                    1
# p190772                                             1                    1
#
#                       cat1               cat2    total  qnty
# id
# p036502  Literacy_Language               None   899.94     2
# p039565     Music_The_Arts      Health_Sports   400.00     1
# p233823       Math_Science  Literacy_Language   469.99     1
# p185307      Health_Sports               None   684.47     5
# p013780      Health_Sports               None   711.00     1
# p063374   Applied_Learning  Literacy_Language   727.36     2
# p103285      Health_Sports               None   414.02     2
# p181781   Applied_Learning  Literacy_Language   414.78     1
# p114989       Math_Science               None   319.80     1
# p191410  Literacy_Language               None   119.76     1
# p030093  Literacy_Language       Math_Science   102.00     1
# p226941  Literacy_Language       Math_Science   733.95     2
# p225747   Applied_Learning  Literacy_Language   176.59    18
# p173555  Literacy_Language               None   871.27     7
# p055350      Special_Needs               None   374.38     3
# p060293  Literacy_Language       Math_Science   110.00     1
# p199435  Literacy_Language       Math_Science   699.98     2
# p074849       Math_Science               None   794.34    15
# p232007   Applied_Learning  Literacy_Language   467.97     5
# p037127   Applied_Learning      Special_Needs   340.87    10
# p230221       Math_Science               None   252.80     2
# p116615   Applied_Learning     Music_The_Arts   299.99     3
# p106275  Literacy_Language               None  1248.00     2
# p070918  Literacy_Language       Math_Science  1356.16     5
# p144291  Literacy_Language               None   286.33    12
# p116102       Math_Science      Special_Needs   359.88     2
# p070029  Literacy_Language       Math_Science   461.91     9
# p107356       Math_Science  Literacy_Language   125.10     1
# p031939  Literacy_Language               None   641.60     1
# p044085  Literacy_Language               None   102.00     2
# ...                    ...                ...      ...   ...
# p046158       Math_Science               None   899.00     1
# p117186   Applied_Learning               None   320.08     4
# p252101  Literacy_Language       Math_Science   101.67     3
# p135316     History_Civics               None   525.58    14
# p021728  Literacy_Language       Math_Science   379.00     1
# p054114      Health_Sports               None   239.88     1
# p034326       Math_Science               None   101.85     3
# p149979  Literacy_Language               None   421.70     1
# p014629  Literacy_Language               None   590.50     7
# p212015      Health_Sports               None   281.75     5
# p110625      Special_Needs               None   311.70     1
# p053417      Health_Sports               None   625.74    13
# p053967  Literacy_Language               None   449.97     1
# p226452  Literacy_Language       Math_Science   358.89     7
# p177332      Special_Needs               None   396.00     1
# p030914  Literacy_Language       Math_Science   399.98     1
# p224932      Health_Sports               None   728.94     3
# p245029      Health_Sports               None   732.00     5
# p154340  Literacy_Language               None   441.55    19
# p235466   Applied_Learning               None   223.06     4
# p068185  Literacy_Language       Math_Science   429.40     4
# p248714  Literacy_Language       Math_Science   319.59     7
# p045565   Applied_Learning  Literacy_Language   535.47     5
# p078709      Health_Sports               None  1228.71    12
# p184627  Literacy_Language      Special_Needs   328.27    40
# p014188       Math_Science               None   253.44     6
# p116452     Music_The_Arts               None   271.99     1
# p074761       Math_Science               None   721.07     9
# p136737  Literacy_Language               None   237.92     1
# p190772  Literacy_Language               None   338.00     2
#
# [182080 rows x 19 columns]

# %%
train2['full_text'] = train2['project_essay_1'].astype(str)+train2['project_essay_2'].astype(str)+train2['project_essay_3'].astype(str)+train2['project_essay_4'].astype(str)
train2['full_text'] = train2['full_text'].str.replace("\\\\r\\\\n",' ').str.replace("\\",'').str.replace("\'",'').str.replace("nannan",'').str.replace('\"','').str.upper()

train2['full_text'][0]
# Out:
# 'MOST OF MY KINDERGARTEN STUDENTS COME FROM LOW-INCOME HOUSEHOLDS AND ARE CONSIDERED AT-RISK. THESE KIDS WALK TO SCHOOL ALONGSIDE THEIR PARENTS AND MOST HAVE NEVER BEEN FURTHER THAN WALKING DISTANCE FROM THEIR HOUSE. FOR 80% OF MY STUDENTS, ENGLISH IS NOT THEIR FIRST LANGUAGE OR THE LANGUAGE SPOKEN AT HOME.   WHILE MY KINDERGARTEN KIDS HAVE MANY OBSTACLES IN FRONT OF THEM, THEY COME TO SCHOOL EACH DAY EXCITED AND READY TO LEARN. MOST STUDENTS STARTED THE YEAR OUT NEVER BEING IN A SCHOOL SETTING. AT THE START OF THE YEAR MANY HAD NEVER BEEN EXPOSED TO LETTERS. EACH DAY THEY SOAK UP MORE KNOWLEDGE AND TRY THEIR HARDEST TO SUCCEED. THEY ARE HIGHLY MOTIVATED TO LEARN NEW THINGS EVERY DAY. WE ARE HALFWAY THROUGH THE YEAR AND THEY ARE STARTING TO TAKE OFF. THEY KNOW KNOW ALL LETTERS, SOME SIGHT WORDS, NUMBERS TO 20, AND A MAJORITY OF THEIR LETTER SOUNDS BECAUSE OF THEIR HARD WORK AND DETERMINATION. I AM EXCITED TO SEE THE PLACES WE WILL GO FROM HERE!I CURRENTLY HAVE A DIFFERENTIATED SIGHT WORD CENTER THAT WE DO DAILY DURING OUR LITERACY STATIONS. THE STUDENTS HAVE ACTIVITIES THAT RELATE TO WHATEVER SIGHT WORD LIST THEY ARE ON. THIS IS ONE OF THEIR FAVORITE STATION ACTIVITIES. I WANT TO CONTINUE TO PROVIDE THE STUDENTS WITH ENGAGING WAYS TO PRACTICE THEIR SIGHT WORDS.   I DREAM OF HAVING THE STUDENTS USE QR READERS TO SCAN THE SIGHT WORDS THAT THEY ARE STRUGGLING WITH AND THE IPODS READING THE SIGHT WORDS WITH THEM. THIS WOULD HELP SO MANY OF MY STUDENTS BY GIVING THEM MULTIPLE EXPOSURES TO THE WORDS. MY STUDENTS NEED SOMEONE WHO CAN GO OVER THESE SIGHT WORDS DAILY AND I CANT ALWAYS GET AROUND TO EVERYONE TO PRACTICE THEIR FLASHCARDS WITH THEM. WITH THE IPODS THEY WOULD STILL HAVE A WAY TO PRACTICE THEIR SIGHT WORDS ON A DAILY BASIS.'

# %%
groups = []
for x in train2.groupby('cat1')['cat1'].head(1):
    if x not in groups: groups.append(x)
groups
# Out:
# ['Literacy_Language',
#  'Music_The_Arts',
#  'Math_Science',
#  'Health_Sports',
#  'Applied_Learning',
#  'Special_Needs',
#  'History_Civics',
#  'Warmth_Care_Hunger']

# %%
text = train2.index +';'+ train2['project_is_approved'].astype(str) +';'+ train2['cat1'].astype(str) +';'+ train2['full_text'].astype(str)

with open(dir+'/consolidated.txt', 'w') as t1: pass
with open(dir+'/consolidated.txt', 'w+') as t1: 
    for line in text:
        try:
            idx,approved,g,line = line.split(';',3)
            clean_line = line.upper()
            clean_line = re.sub("\\\\[RNT]", "", clean_line)
            clean_line = re.sub("[^A-Z ]+", " ", clean_line)
            clean_line = re.sub("\s\s+", " ", clean_line)
            clean_line = re.sub("NANNAN", "", clean_line)
            con = Counter(clean_line.split()).items()
            for item in con:
                a,b = item

                t1.write(str(idx)+';'+str(approved)+';'+str(g)+';'+str(a) + ';' + str(b) + '\n')
        except:
            print('.', end='',flush=True)

# %%
for group in groups:
    with open(dir+'consolidado_'+group+'_0.txt', 'r') as t0:
        sorted_file = sorted(t0)
    with open(dir+'consolidado_'+group+'_0_sorted.txt', 'w') as f:
        f.writelines(sorted_file)
    with open(dir+'consolidado_'+group+'_1.txt', 'r') as t1:
        sorted_file = sorted(t1)
    with open(dir+'consolidado_'+group+'_1_sorted.txt', 'w') as f:
        f.writelines(sorted_file)

# %%
approved = pd.read_csv(dir+'consolidado_'+group+'_1_sorted.txt', sep = ' ', header=None)
not_approved = pd.read_csv(dir+'consolidado_'+group+'_0_sorted.txt', sep = ' ', header=None)

# %%
asum = approved.groupby(0)[1].sum()
bsum = not_approved.groupby(0)[1].sum()

# %%
acount = approved.groupby(0)[1].count()
bcount = not_approved.groupby(0)[1].count()

a = len(acount)
b = len(bcount)

# %%
c = pd.concat([acount,asum,bcount,bsum], keys=['approved_count','approved_sum','not_approved_count',
                                               'not_approved_sum'], axis=1).fillna(0)
c['sum_count'] = c['approved_count'] + c['not_approved_count']
c['sum_sum'] = c['approved_sum'] + c['not_approved_sum']
c = c[(c['sum_count'] > 3) & (c['not_approved_sum'] >1)]  
c['importance'] = (c['approved_count']*b - c['not_approved_count']*a) / (c['sum_count']*(a+b))
c['importance_sq'] = c['importance']  * c['importance'] 
c.sort_values('importance_sq', ascending=False, inplace=True)
c.to_pickle('DONORSCHOOSE\words.pickle')
c = c.head(16000)
c

# %%
c = pd.read_pickle('DONORSCHOOSE\words.pickle')

# %%
c

# %%
c[c.importance <0]
