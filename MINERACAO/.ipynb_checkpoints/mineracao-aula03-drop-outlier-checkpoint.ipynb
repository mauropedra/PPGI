# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats as st
import warnings
import math

warnings.simplefilter('ignore')
matplotlib.rcParams['figure.figsize'] = (10, 10)
matplotlib.style.use('seaborn')
# %matplotlib inline

# %%
arr = pd.Series([181.37984274, 154.80600659, 182.33424888, 170.32065307, 179.82634437,
       168.73723578, 164.28520413, 171.93415101, 171.71090179, 177.69136458,
       153.38183565, 151.13269527, 166.4994225,  828.37581774 ,168.02278222,
       169.29065423, 138.46062748, 174.88588464, 155.01472584, 164.27356639])

arr = arr[arr<800]
arr
# Out:
# 0     181.379843
# 1     154.806007
# 2     182.334249
# 3     170.320653
# 4     179.826344
# 5     168.737236
# 6     164.285204
# 7     171.934151
# 8     171.710902
# 9     177.691365
# 10    153.381836
# 11    151.132695
# 12    166.499423
# 14    168.022782
# 15    169.290654
# 16    138.460627
# 17    174.885885
# 18    155.014726
# 19    164.273566
# dtype: float64

# %% [markdown]
# ## 1) Qual a média da amostra?

# %%
print('average: ',np.average(arr))
# Out:
# average:  166.525691956

# %% [markdown]
# ## 2) Qual o desvio padrão da amostra?

# %%
print('std dev population: ',np.std(arr, ddof=0))
print('std dev sample: ',np.std(arr, ddof=1))
# Out:
# std dev population:  11.24989948944472
# std dev sample:  11.558172990787764

# %% [markdown]
# ## 3) Faça um histograma com os dados.

# %%
plt.xlabel('values')
plt.ylabel('Frequency')
plt.title('Histogram of data input')
plt.grid(True)
plt.hist(arr, bins=10, rwidth=0.9)
plt.show()

# %%
DISTRIBUTIONS = [st.alpha,st.anglit,st.arcsine,st.argus,st.beta,st.betaprime,st.bradford,st.burr,st.burr12,st.cauchy,
                 st.chi,st.chi2,st.cosine,st.crystalball,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponpow,
                 st.exponweib,st.f,st.fatiguelife,st.fisk,st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.gamma,
                 st.genlogistic,st.genpareto,st.gennorm,st.genexpon,st.dgamma,st.genextreme,st.gausshyper,st.gamma,
                 st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,st.gumbel_l,st.halfcauchy,
                 st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,st.invweibull,
                 st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,st.logistic,
                 st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,st.nct,
                 st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,st.rayleigh,
                 st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
                 st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy] 

def plothist(x, distfn, args, loc, scale, right=1):
    plt.figure()
    # the histogram of the data
    n, bins, patches = plt.hist(x, 25, normed=1, facecolor='green', alpha=0.75)
    maxheight = max([p.get_height() for p in patches])
    axlim = list(plt.axis())
    axlim[-1] = maxheight*1.05
    pdfpoints = bins + np.diff(bins)[0]*np.linspace(-0.5,0.5,11)[:,np.newaxis]
    pdfpoints = np.sort(pdfpoints.ravel())
    yt = distfn.pdf(pdfpoints, loc=loc, scale=scale, *args)
    yt[yt>maxheight] = maxheight
    lt = plt.plot(pdfpoints, yt, 'r--', linewidth=1, label='estimated')
    ys = st.t.pdf(pdfpoints, 10, scale=10,)*right
    ls = plt.plot(pdfpoints, ys, 'b-', linewidth=1, label='true')
    plt.legend()
    plt.xlabel('values')
    plt.ylabel('Probability')
    plt.title(r'$\mathrm{Fitting\ Distribution\ %s :}\ \mu=%f,\ \sigma=%f$'%(distfn.name,loc,scale))
    plt.grid(True)
    plt.show()

# %%
rvs = st.t.rvs(10, scale=10, size=500)
mles,d = [],[]

for distr in DISTRIBUTIONS:
    try:
        distname = distr.name
        par_est = distr.fit(rvs,loc=np.average(arr), scale=np.std(arr, ddof=1))
        arg_est = par_est[:-2]  # get scale parameters if any
        loc_est = par_est[-2]
        scale_est = par_est[-1]
        rvs_normed = (rvs-loc_est)/scale_est
        ks_stat, ks_pval = st.kstest(rvs_normed,distname, arg_est)
        if ks_stat < 1 and ks_pval > 0: 
            print('\nFitting distribution',distname)
            print('estimated distribution parameters\n', par_est)
            print('ks-stat =',ks_stat,', ks-pval =',ks_pval)
            plothist(rvs, distr, arg_est, loc_est, scale_est, right = 1)
            pars = distr.fit(arr)
            mle = distr.nnlf(pars, arr)
            mles.append(mle)
            d.append(distname)
    except:
        print('erro em:', distr.name)
# Out:
# Fitting distribution cauchy
# estimated distribution parameters
#  (0.15877662051266894, 6.3733618767936315)
# ks-stat = 0.0747284741239 , ks-pval = 0.00711497068883
# Fitting distribution crystalball
# estimated distribution parameters
#  (8.6769985098987803, 1.004895422058306, -0.037736558741900073, 10.901766793904866)
# ks-stat = 0.0325549112095 , ks-pval = 0.664343099197
# Fitting distribution exponnorm
# estimated distribution parameters
#  (0.028744844205290505, -0.35423559382418307, 10.89765919058167)
# ks-stat = 0.0326643579151 , ks-pval = 0.660216529671
# Fitting distribution frechet_l
# estimated distribution parameters
#  (4.1514844764648782, 41.593216615644337, 45.719834489274639)
# ks-stat = 0.0471234740704 , ks-pval = 0.210343439904
# Fitting distribution genlogistic
# estimated distribution parameters
#  (0.9118203913444638, 0.91995680170393834, 5.923768689599866)
# ks-stat = 0.0210853422261 , ks-pval = 0.979328566952
# Fitting distribution gennorm
# estimated distribution parameters
#  (1.6899374168820325, 0.0010706066089164056, 13.919786693976278)
# ks-stat = 0.0189797780076 , ks-pval = 0.993739296253
# Fitting distribution dgamma
# estimated distribution parameters
#  (1.355461885558132, 0.050584361721114149, 6.28996420041815)
# ks-stat = 0.0265233083916 , ks-pval = 0.873311835119
# Fitting distribution genextreme
# estimated distribution parameters
#  (0.24087897557668492, -4.1266275835737432, 11.012918044148087)
# ks-stat = 0.0471239707591 , ks-pval = 0.210333518486
# Fitting distribution gumbel_r
# estimated distribution parameters
#  (-5.5406170060476452, 11.204063439112794)
# ks-stat = 0.0926642727008 , ks-pval = 0.000346344849251
# Fitting distribution gumbel_l
# estimated distribution parameters
#  (5.3874430768640398, 11.128335337362103)
# ks-stat = 0.0703681275996 , ks-pval = 0.0134502557702
# Fitting distribution hypsecant
# estimated distribution parameters
#  (0.11323861022772977, 7.3069657872213511)
# ks-stat = 0.026297421749 , ks-pval = 0.879726528241
# Fitting distribution johnsonsu
# estimated distribution parameters
#  (0.28360164644851271, 2.8932595971169457, 3.0400278796962952, 29.565753393656749)
# ks-stat = 0.0187169974317 , ks-pval = 0.99476924513
# Fitting distribution laplace
# estimated distribution parameters
#  (-0.12997582233091509, 8.5246462744974778)
# ks-stat = 0.0545423358886 , ks-pval = 0.0983963371377
# erro em: levy_stable
#
# Fitting distribution logistic
# estimated distribution parameters
#  (0.074387220727843595, 6.1267310174878888)
# ks-stat = 0.0197817308684 , ks-pval = 0.989649782828
# Fitting distribution loggamma
# estimated distribution parameters
#  (358.3230510979987, -1212.5637298176212, 206.21053907967581)
# ks-stat = 0.0305221235302 , ks-pval = 0.740143245416
# Fitting distribution nct
# estimated distribution parameters
#  (14.219421010715422, -0.43656502387619411, 4.6090187034473553, 10.08197950387849)
# ks-stat = 0.019266591011 , ks-pval = 0.992448800812
# Fitting distribution norm
# estimated distribution parameters
#  (-0.037736600933973935, 10.901766777206117)
# ks-stat = 0.0325549122201 , ks-pval = 0.6643430611
# Fitting distribution powernorm
# estimated distribution parameters
#  (1.5014321548411145, 4.1792860124556199, 12.238016437809154)
# ks-stat = 0.0289218922185 , ks-pval = 0.797084732437
# Fitting distribution t
# estimated distribution parameters
#  (14.810239910631555, 0.01582753075163576, 10.148029227906761)
# ks-stat = 0.0212921673074 , ks-pval = 0.977210816487
# Fitting distribution weibull_max
# estimated distribution parameters
#  (4.1514844764648782, 41.593216615644337, 45.719834489274639)
# ks-stat = 0.0471234740704 , ks-pval = 0.210343439904

# %%
plt.barh(d,mles)
plt.show()

# %% [markdown]
# ## 4) Qual distribuição se enquadra melhor para os dados?

# %%
results = [(dist, mle) for dist, mle in zip(d, mles)]
print(results)
fit = sorted(zip(d,mles), key=lambda d: d[1])
best_fit = fit[0]
print(best_fit)
print ('Best fit reached using {}, MLE value: {}'.format(best_fit[0], best_fit[1]))
# Out:
# [('cauchy', 75.462372085215833), ('crystalball', inf), ('exponnorm', 72.946759771102222), ('frechet_l', 70.196555088073794), ('genlogistic', 72.189437669270745), ('gennorm', 72.942258342415428), ('dgamma', 70.610432434764107), ('genextreme', 70.931269397029538), ('gumbel_r', 76.055436564009966), ('gumbel_l', 71.738653137694627), ('hypsecant', 73.186819166285659), ('johnsonsu', 71.646668178471515), ('laplace', 73.064574846958223), ('logistic', 73.072572783789923), ('loggamma', 71.728528964787074), ('nct', 73.236153440674471), ('norm', 72.946656823328595), ('powernorm', 71.789979546657591), ('t', 72.946656868399415), ('weibull_max', 70.196555088073794)]
# ('frechet_l', 70.196555088073794)
# Best fit reached using frechet_l, MLE value: 70.1965550880738

# %%
parameters = st.weibull_max.fit(arr)
parameters
# Out:
# (0.28790793335408055, 182.33424888000002, 1.408135081395312)

# %%
par_est = st.weibull_max.fit(arr)
print(par_est)
arg_est = par_est[:-2]
loc_est = par_est[-2]
scale_est = par_est[-1]
plothist(arr, st.weibull_max, arg_est, loc_est, scale_est, right = 1)
# Out:
# (0.28790793335408055, 182.33424888000002, 1.408135081395312)

# %% [markdown]
# ## 5) Infira a média da população a partir da amostra.

# %%
print('estimated mean from population: ',par_est[1])
# Out:
# estimated mean from population:  182.33424888

# %% [markdown]
# ## 6) Infira o desvio padrão da população a partir da amostra.

# %%
print('estimated standard deviation from population: ',par_est[2])
# Out:
# estimated standard deviation from population:  1.4081350814

# %% [markdown]
# ## 7) Considerando a média e desvio padrão que você inferiu a partir da amostra e a distribuição que você hipotetizou sobre os dados,  qual a probabilidade de:

# %% [markdown]
# #### encontrar o valor 200.00

# %%
print('P(x=200) = ',st.weibull_max.pdf(200, par_est[0], loc = par_est[1], scale=par_est[2])*100,'%')
# Out:
# P(x=200) =  0.0 %

# %% [markdown]
# #### o valor ser maior que 180

# %%
print('P(x>180) = ',(1-st.weibull_max.cdf(180, par_est[0], loc = par_est[1], scale=par_est[2]))*100,'%')

x = np.linspace(100,250,100)
plt.plot(x,st.weibull_max.pdf(x, par_est[0], loc = par_est[1], scale=par_est[2]))
plt.axvline(x=180, color='r', linestyle='--')
plt.show()
# Out:
# P(x>180) =  68.545739521 %

# %% [markdown]
# #### o valor ser menor que 120 e maior que 190

# %%
print('P(x<120 and x>190) = ',(st.weibull_max.cdf(120, par_est[0], loc = par_est[1], scale=par_est[2])+
                               1-st.weibull_max.cdf(190, par_est[0], loc = par_est[1], scale=par_est[2]))*100,'%')

x = np.linspace(100,250,100)
plt.plot(x,st.weibull_max.pdf(x, par_est[0], loc = par_est[1], scale=par_est[2]))
plt.axvline(x=120, color='r', linestyle='--')
plt.axvline(x=190, color='r', linestyle='--')
plt.show()
# Out:
# P(x<120 and x>190) =  5.08960944311 %

# %% [markdown]
# ## 8) Utilizando um grid search (um for dentro de outro igual ao utilizado na aula prática), encontre o conjunto de parâmetros da sua distribuição que maximiza o log-likelihood para os dados. Por exemplo, se você no item 4 supôs que esses dados seguem uma distribuição exponencial, você terá que achar o melhor lambda (taxa) que faz a distribuição exponencial se encaixar nos seus dados (qual lambda aumenta o likelihood).

# %%
best_df = None
best_mean = None
best_std = None
best_ML = -np.inf
df_ = np.linspace(0.01, 5)
mean_ = np.linspace(min(arr), max(arr))
std_ = np.linspace(0,10)

# %%
for _mean in mean_:
    for _std in std_:
        for _df in df_:
            y = st.weibull_max.pdf(arr,_df,loc=_mean,scale=_std)
            #print(y, flush=True)
            log_likelihood = np.sum(np.log(y))
            if (log_likelihood - best_ML) > 0.0001 :
                best_ML = log_likelihood
                best_mean = _mean
                best_std = _std
                best_df = _df
                print(best_df,best_mean,best_std,best_ML, flush=True)
# Out:
# 0.01 182.33424888 0.204081632653 inf

# %%
precision = 0.2
for p in range(5):
    df_ = np.linspace(best_df*(1-precision), best_df*(1+precision))
    mean_ = np.linspace(best_mean*(1-precision), best_mean*(1+precision))
    std_ = np.linspace(best_std*(1-precision), best_std*(1+precision))
    for _mean in mean_:
        for _std in std_:
            for _df in df_:
                y = st.t.pdf(arr,_df,loc=_mean,scale=_std)
                #print(y, flush=True)
                log_likelihood = np.sum(np.log(y))
                if (log_likelihood - best_ML) > 0.0001 :
                    best_ML = log_likelihood
                    best_mean = _mean
                    best_std = _std
                    best_df = _df
                    print(best_df,best_mean,best_std,best_ML, flush=True) 
    precision /= 2

# %% [markdown]
# ## 9) A média e desvio padrão para a distribuição com os parâmetros encontrados no item 8 são próximos da média e desvio padrão da amostra? Se não, qual seria o motivo?

# %%
print('método biblioteca scipy:',par_est)
print('método naïve:',best_df,best_mean,best_std)
print('calculado da amostra:',np.average(arr),np.std(arr, ddof=1))
print('Não, principal motivo é que o peso de valores fora da distribuição (outliers) são diferentes.')
# Out:
# método biblioteca scipy: (0.28790793335408055, 182.33424888000002, 1.408135081395312)
# método naïve: 0.01 182.33424888 0.204081632653
# calculado da amostra: 166.525691956 11.558172990787764
# Não, principal motivo é que o peso de valores fora da distribuição (outliers) são diferentes.

# %% [markdown]
# ## 10) Nos últimos 4 anos a empresa D&B teve um faturamento mensal médio de 50 milhões com um desvio padrão de 5 milhões.  Após a contratação de uma empresa especializada em marketing digital, os últimos seis meses apresentaram os faturamentos de 61 milhões, 54 milhões, 78 milhões, 42 milhões, 78 milhões e 73 milhões. Considerando esses seis meses como uma amostra, calcule a probabilidade dessa empresa ter melhorado o resultado do faturamento por puro acaso (dica: considerando o teorema central do limite, qual a probabilidade da média amostral  ocorrer por puro acaso, uma vez que ora ou outra resultados maiores ou menores podem ocorrer)

# %%
mi_0 = 50
sd_0 = 5
fat = [61,54,78,42,78,73]
mi_fat = np.mean(fat)

print((1 - st.norm.cdf(mi_fat,loc=50, scale=5))*100,'%')

x = np.linspace(40,80,100)
plt.plot(x,(st.norm.pdf(x,loc=50, scale=5)))
plt.axvline(x=mi_fat, color='r', linestyle='--')
plt.show()
# Out:
# 0.207409836359 %
